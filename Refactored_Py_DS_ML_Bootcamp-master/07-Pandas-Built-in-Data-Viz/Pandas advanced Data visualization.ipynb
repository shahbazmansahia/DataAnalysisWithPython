# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt;
import seaborn as sns;
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col = 0);

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2');

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
df1['A'].hist(bins = 30);

# %%
# you can call entire df or a col in the df and call plot on it
df1['A'].plot(kind = 'hist');

# %%
df1['A'].plot(kind = 'hist', bins = 30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['A'].plot.hist();

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
# area plot
df2.plot.area();

# %%
df2.plot.area(alpha = 0.4);

# %%
# good for categorical vals:
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked = True);

# %%
df1['A'].plot.hist();

# %%
df1['A'].plot.hist(bins = 50);

# %%
df1.plot.line();

# %%
df1.plot.line(x= df1.index, y = 'B'); #UPDATE: pandas auto-takes the index now so we don't need to pass it as 'x' anymore
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_84688/1022453473.py in <module>
# ----> 1 df1.plot.line(x= df1.index, y = 'B'); #UPDATE: pandas auto-takes the index now so we don't need to pass it as 'x' anymore
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwargs)
#    1038         as coordinates.
#    1039         """
# -> 1040         return self(kind="line", x=x, y=y, **kwargs)
#    1041
#    1042     @Appender(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     935                 if is_integer(x) and not data.columns.holds_integer():
#     936                     x = data_cols[x]
# --> 937                 elif not isinstance(data[x], ABCSeries):
#     938                     raise ValueError("x must be a label or position")
# ...

# %%
df1.plot.line(y = 'B');

# %%
df1.plot.line(y = 'B', figsize = (12, 3), lw = 1);

# %%
df1.plot.scatter(x = 'A', y = 'B');

# %%
df1.plot.scatter(x = 'A', y = 'B', c = 'C'); # This is a 3d plot now with the colors defining it

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.scatter(x = 'A', y = 'B', c = 'C', cmap = 'magma'); # This is a 3d plot now with the colors defining it

# %%
# we can also assign diff. vals. diff. sizes on the graph to distinguish them
df1.plot.scatter(x = 'A', y = 'B', s=df1['C']* 100); # This is a 3d plot now with the size defining it

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
# for bivariate data:
df = pd.DataFrame(np.random.randn(1000, 2), columns = ['a', 'b']);

# %%
df.head()
# Out:
#           a         b
# 0 -0.273186 -0.835077
# 1  0.727569 -1.324299
# 2  0.447754 -1.411940
# 3  0.734362 -1.769365
# 4 -0.488183  0.728108

# %%
# since this is a bivariate df
df.plot.hexbin (x = 'a', y = 'b');

# %%
df.plot.hexbin (x = 'a', y = 'b', gridsize = 25);

# %%
df.plot.hexbin (x = 'a', y = 'b', gridsize = 25, cmap = 'coolwarm');

# %%
df2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# same as kde
df2['a'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density();
